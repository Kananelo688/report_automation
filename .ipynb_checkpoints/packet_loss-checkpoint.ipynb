# %%
import data_processing as dp
import openpyxl as xl
from openpyxl.styles import PatternFill, Font

# %%
def insert_data(kpi,routers,sheet=None,task='3G',conditional_format=50.00):
    """
    Inserts data of the given KPI into the given worksheet.

    ---------
    Parameters:
    sheet(openpyxl Worksheet): an object of Worksheet, which represent the sheet to which data will be written
    kpi(data_processing KPI): an object of KPI class, which has its data already initialized from the spread_sheets
    """
    dates = list()
    site_names = list()
    cell_font = Font(color = "FFB22222")
    bold_font = Font(bold= True)
    bold_color_font = Font(bold= True, color = "FFB22222")
    cell_fill = PatternFill(start_color="FFCCCC", end_color="FFCCCC", fill_type="solid")
    number_format_4G = '%'
    for key in kpi.data.keys():
        if key[0] not in dates:
            dates.append(key[0])
        if key[1] not in site_names:
            site_names.append(key[1])
    
    sheet.cell(row = 1, column = 1).value = kpi.kpi_name
    sheet.cell(row = 1, column = 1).font = bold_font
    for date in dates:
        sheet.cell(row = 2, column = dates.index(date)+2).value = date
        sheet.cell(row = 2, column = dates.index(date)+2).font = bold_font
    router_data = dict()
    for router in routers:
        for date in dates:
            router_data[(date,router)] = list()
            for key in kpi.data:
                if '4G_' in key[1] or '3G_' in key[1]:
                    if key[0] == date and key[1][3:] in routers[router]:
                        router_data[(date,router)].append(kpi.data[key])
                else:
                    if key[0] == date and key[1] in routers[router]:
                        router_data[(date,router)].append(kpi.data[key])
    dump_kpi = dp.KPI('dump',kpi.agg_fun)
    dump_kpi.generate_pivot_table(router_data)
    router_data = dump_kpi.data
    #Now have to write the data to the external sheet
    row_num = 3
    for router in routers:
        sheet.cell(row = row_num, column = 1).value = router
        sheet.cell(row = row_num, column = 1).font = bold_font
        for date in dates:
            sheet.cell(row = row_num, column = dates.index(date)+2).value = router_data[(date,router)]
            sheet.cell(row = row_num, column = dates.index(date)+2).font = bold_font
            if router_data[(date,router)]>conditional_format:
                sheet.cell(row = row_num, column = dates.index(date)+2).font = bold_color_font
                sheet.cell(row = row_num, column = dates.index(date)+2).fill = cell_fill
        
        for site in routers[router]:
            row_num +=1
            if task+'_'+site in site_names:
                site = task+'_'+site
            elif site in site_names:
                pass
            else:
                row_num-=1
                continue
            sheet.cell(row = row_num,column = 1).value = site
            
            for date in dates:
                sheet.cell(row = row_num,column = dates.index(date)+2).value = kpi.data[(date,site)]
                if kpi.data[(date,site)]>conditional_format:
                    sheet.cell(row = row_num,column = dates.index(date)+2).font = cell_font
                    sheet.cell(row = row_num, column = dates.index(date)+2).fill= cell_fill
                if task == '4G':
                    sheet.cell(row = row_num,column = dates.index(date)+2).number_format = number_format_4G
                    
                    
        row_num+=1

# %%
def compile_report(filename_4G_stats, filename_3G_stats,destination_filename = 'Packetloss',verbose = False):
    """
    Computes Packet Loss Report, given 4G and 3G statistics filenames(.xlsx files).

    ---------
    Parameters:
    filename_4G_stats(str): File name of the combined 4G Statistics exported from the management(combined SDR and ITBBU).
    
    filename_3G_stats(str): Filename of the  3G Daily Packet Info stats.
    
    destination_filename(str): Filename of the destination report. Defaults to 'Packetloss'
    
    verbose(Bool): Flag used for debugging, if set to True, print the progress of report compilation.
    """

    if verbose:
        print('Load files...',end= '', flush = True)
    wb_4G = xl.load_workbook(filename_4G_stats)
    wb_3G = xl.load_workbook(filename_3G_stats)
    if verbose:
        print('done.\nCreating Report workbook and Adding Sheets...',end = '' , flush = True)
    report_wb = xl.Workbook()
    report_wb.create_sheet('3G PACKET LOSS')
    report_wb.create_sheet('3G PACKET DELAY')
    report_wb.create_sheet('3G PACKET JITTER')
    report_wb.create_sheet('VoLTE LOSS')
    if verbose:
        print('done.\nCreating KPIs...')
    kpi_4G_volte_loss = dp.KPI('DL S1-U RTP Packet Loss Rate of QCI1(%)','mean')
    kpi_3G_packet_loss = dp.KPI('Rate of Lost Detected-Packet(1/10000)','sum')
    kpi_3G_delay = dp.KPI('Mean End-to-End Delay of Detected Packe(ms)','max')
    kpi_3G_jitter = dp.KPI('Mean Jitter of Detected Packet(ms)','max')
    if verbose:
        print('done.\nPerforming Text to columns...',end = '', flush = True)
    dp.text_to_columns(wb_4G['Sheet0'],1)
    dp.text_to_columns(WB_3G['Sheet0'],1)
    if verbose:
        print('done.\nReading data from spreadsheets...',end = '' , flush = True)
    kpi_4G_volte_loss.generate_pivot_table(dp.pivot_table_data(wb_4G['Sheet0'],['Begin','ENBFunction Name'],kpi_4G_volte_loss.kpi_name))
    kpi_3G_packet_loss.generate_pivot_table(dp.pivot_table_data(wb_3G['Sheet0'],['Begin','Office Name'],kpi_3G_packet_loss.kpi_name))
    kpi_3G_delay.generate_pivot_table(dp.pivot_table_data(wb_3G['Sheet0'],['Begin','Office Name'],kpi_3G_delay.kpi_name))
    kpi_3G_jitter.generate_pivot_table(dp.pivot_table_data(wb_3G['Sheet0'],['Begin','Office Name'],kpi_3G_jitter.kpi_name))
    if verbose:
        print('done.\nCompiling report...')
    routers = dict()
    for key in ROUTER_LOOKUP:
        if ROUTER_LOOKUP[key] in routers:
            routers[ROUTER_LOOKUP[key]].append(key)
        else:
            routers[ROUTER_LOOKUP[key]]  = [key]

# %%
wb_4G =xl.load_workbook('4G Combined KPIs.xlsx')

# %%
wb_3G = xl.load_workbook('3G Daily Packet Info.xlsx')

# %%
#sheet_4G = wb_4G.active
sheet_3G = wb_3G.active

# %%
dp.text_to_columns(sheet_3G,1)

# %%
wb_3G.save('3G_packet_loss.xlsx')

# %%
data = dp.pivot_table_data(sheet_3G,['End','Office Name'],'Rate of Lost Detected-Packet(1/10000)')

# %%
umts_loss = dp.KPI('Rate of Lost Detected-Packet(1/10000)','sum')

# %%
umts_loss.generate_pivot_table(data)

# %%
umts_loss.data
# Out:
# {(datetime.datetime(2025, 4, 28, 0, 0), '3G_THABA-TSEKA HILL'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIBONO'): 192.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAFETENG EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LCE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABALIHLOLO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LINAKANENG'): 26144.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALEFILOANE'): 465.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALEFILOANE REPEATER'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QHOASING'): 716.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NKA-O-BEE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BULARA'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BAKING'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOTA'): 22.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPUTSOE_WASA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOSETOA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SESHOTE'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_POPA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NKOKAMELE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ST. JAMES'): 8011.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEJONE'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TLOKOENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAFETENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHLONG'): 24.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SILOE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATELILE'): 96.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOHALE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOHALESHOEK EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA NYANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KATSE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEOKA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), 'SGSN'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NGOAJANE'): 8846.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BEREAPLATEAU'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAQHAKA'): 199.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_AME'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LESOBENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ROTHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHLOENYENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAJA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAMOKHALINYANE'): 1195.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAJANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MORIJA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABABOSIU'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HALEKOALA'): 16.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MACHACHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RADIOLESOTHO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BATI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKOETJE'): 239.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALAOANENG'): 537.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MANTSONYANE'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATHUOANENG'): 66041.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NYAKOSOBA'): 69779.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA QABA'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEMONKONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSOLOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PEKA'): 92500,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PITSENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEBOCHE'): 530.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SETLAKALLENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIPHIRING'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LERIBEMORENENG'): 352.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HLEOHENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MERITING'): 22,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_CALEDON'): 269.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHOBONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAMOTSOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAKAMOHO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SERUTLE'): 708.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSIKOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QHOLAQHOE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_CHAFO'): 52.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NYENYE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_CORNEXCHANGE'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LISEMENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSIFALIMALI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSEHLANYANE'): 49.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAZENOD_AIRPORT'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHLASELA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOSALEMANE'): 120000,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOTSOLA'): 82.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPOTENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKHOROANA'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEKOKOANENG'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOLONYAMA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAMATHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEFIKENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THAKABANNA'): 176.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIQHOBONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LETSENG'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKOAE2'): 710.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BAFALI'): 205.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_METOLONG'): 1427.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MONONTSA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOREMOHOLO'): 243.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHANYANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MABOLOKA'): 27099.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SETALA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NTJABANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NQECHANE'): 1371.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA_NTSELI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOABONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTHAE_MINE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_POLIHALI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PONOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATSOKU'): 17957.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOKHONG'): 98789.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIQHOBONG_MINE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KAO_MINE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TLOKOTSING'): 8.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA SHOAEPANE'): 23368.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATLAKENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MANAMANENG'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PANENG'): 257.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABA-NTSHO'): 42945.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA KOATSI'): 19537.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MARAKABEI'): 371.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPHOLANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SOLANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTETE_SEKHOBE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QHOALI_HA_KELEBONE'): 2813.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOTLONG_VALLEY'): 193.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKOAE_1'): 218.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIQOBONG'): 1143.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KETANE'): 707.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KETANE_TIPING'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHATIBE_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHOSHANENG'): 25107.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_UPPER_MOYENI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAMAEPHO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTSEKUOA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOBATSI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKHAKHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SANQEBETHU'): 8058.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAMOHAPI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSAKHOLO'): 30.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KUBUNG'): 1071.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIKHOELE'): 77202.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA_NTOPO'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HOLYCROSS'): 57.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKHALENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALIMONG'): 22010.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TIPING'): 108135.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEROALANKHOANA'): 94380.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOSENEKE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHLAKACHANENG'): 718.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA_MPUTANA'): 22.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSIME'): 27.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA RAMABANTA'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEPHAPHOS GATE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SETIBING'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_VANROOYAN'): 16.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEBELONYANE'): 718.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATEBENG'): 58488.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HIGHVELT'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOINYATSO'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSOLO2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA_ECOL'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOTLONG_TOWN'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BESELE'): 8.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LOWER_THAMAE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LESOTHOSUN'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LAKESIDE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_VICTORIA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MANONYANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_STATE LIBRARY'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASERU WEST'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_FOKOTHI'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MABOTE'): 200,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_STADIUM'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ABIA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSANE_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ROYAL PALACE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QOALING'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ETLHQ'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_INDUSTRIAL1'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LITHOTENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LESOTHOHIGHSCHOOL'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASIANOKENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTIMPOSO'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LITHABANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA2'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HILLSVIEW'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSANE_INDUSTRIAL'): 38.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HATSIU'): 197.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HATHAMAE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA1'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TIKOE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEQELE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_FLORIDA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QOALING_HAMAMPHO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKOANYANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MABOTEPOLICE'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_FOSO'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_AIRPORT'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THUATHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SHALABENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOROKHOANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_INDUSTRIAL2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NALELI'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HLALELE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASERUSUN'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_CARLTONCENTRE'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RALEJOE'): 68.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ROMAEXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASOWE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOALABATA'): 200,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEAPOINT'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PENAPENA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATALA'): 139457.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NNELESE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSOLO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPELENG'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ROMA_HA_SKAUT'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA_WILLIS'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_FOSO_2'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA_DLM'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOSHOESHOE_II'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSANE_LESIA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSANE_LEKHOOA'): 60389.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LOWER_SEOLI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA_SELESO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEQELE_BUSSTOP'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEKAMANENG'): 200,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTSEMOCHA'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEBOTHOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOSOFO'): 11363.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASANA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBETSOANA_LECOOP'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_COW'): 190000,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOCHABELA'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HATLELAI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MORIFI'): 71.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MPHAKI'): 716.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEBAPALA'): 4840.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEHLABATHEBE'): 49402.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SOURU'): 130.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BRAAKFONTEIN'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA MPITI'): 136.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PHATLALLA'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOTLONG_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOUNT MOOROSI'): 49.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTSEMOCHA2'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATALA_PHASE2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAJAHENG'): 8.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NHTC'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPETLA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEQELE_2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOALABATA_PRIMARY'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBELU'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TSOSANE_PRIMARY'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKHOATHI'): 6219.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTLOHELOA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAZENOD'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSANELESIA2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PARLIAMENT'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASOWE_1'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEKAMANENG_2'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RATJOMOSE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MANTSEBO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PARAY_HOSPITAL'): 361,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PONTSENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOFOKA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ST_AGNES'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ROMA_HATABUTLE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TEYATEYANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BEREA_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BUTHA BUTHE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LERIBE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPUTSOE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIKILENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ST_ROSE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHETHOANENG'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SANIBORDER'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOTISPHOLA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOKHOTLONGHILL'): 7936.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_NYENYE_2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SHEPESELI'): 10099.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MARABENG'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MASERUMALL_2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALETSUNYANE'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KUBAKE'): 6173.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PULANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATHATA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MANKOANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAKEPI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATUKENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKOPO'): 1725,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PALACE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAMOPELI'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATLAMENG'): 24.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA SETHO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATHATA2'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAQELE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAHLAKAPESE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BUOASONO'): 194.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QACHA'): 138.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAMOROBA'): 82.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA SEHLOHO'): 4799.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QUTHING_LNBS'): 36051.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_DR_GUESTHOUSE'): 197,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHUBELU_VALLEY'): 151038.75,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BOKONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ALWYNSKOP'): 30.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIQALABENG'): 141.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAMOKHELE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOHALESHOEKHILL'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA-NTHO'): 3930.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATHOLENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PHAHAMENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPHOHLOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KOLO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABANA_MORENA'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALUMENG'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LELOALENG'): 11.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_ST_STEPHENS'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_QALAKHENG'): 8.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEROPONG'): 136.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_GOLDEN_TOWER'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABA TSEKA_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HALEPOLESA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALEALEA'): 30.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MPHARANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THABA_PUTSOA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAPOTENG_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_TOLOANE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PITSENG_POLICE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALESAOANA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_BUTHABUTHE_TLOKOENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LEVISNEK'): 191.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KHAFUNG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAQOALA_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HAMOTAU'): 22.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_THETSINYANE'): 710.0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HATLALI'): 70544.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEHONGHONG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAMAEBANA'): 34236.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_KAONYANE'): 8.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LIKHELIKA'): 80.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_JANTEU'): 8727.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAPOLEBOEA'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MATSOAING'): 8691.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_SEATE'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALINGOANENG'): 682.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MALEHLAKANA'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_LINAKANENG_2'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MOTENG_2'): 5.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_PATISING'): 54216.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MAKHANGOA'): 8619.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAMATSELISO'): 34896.5,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MESITSANENG'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA SEHAPA'): 126122.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_HA TSEPO'): 0,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_RAPOKOLANA'): 92704.25,
#  (datetime.datetime(2025, 4, 28, 0, 0), '3G_MJANYANE'): 136.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABA-TSEKA HILL'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIBONO'): 228.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAFETENG EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LCE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABALIHLOLO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LINAKANENG'): 21485.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALEFILOANE'): 644.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALEFILOANE REPEATER'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QHOASING'): 1238.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NKA-O-BEE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BULARA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BAKING'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOTA'): 33.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPUTSOE_WASA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOSETOA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SESHOTE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_POPA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NKOKAMELE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ST. JAMES'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEJONE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TLOKOENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAFETENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHLONG'): 53249.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SILOE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATELILE'): 88.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOHALE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOHALESHOEK EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA NYANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KATSE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEOKA'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), 'SGSN'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NGOAJANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BEREAPLATEAU'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAQHAKA'): 38.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_AME'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LESOBENG'): 11.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ROTHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHLOENYENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAJA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAMOKHALINYANE'): 1245.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAJANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MORIJA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABABOSIU'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HALEKOALA'): 27.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MACHACHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RADIOLESOTHO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BATI'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKOETJE'): 217.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALAOANENG'): 669.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MANTSONYANE'): 22.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATHUOANENG'): 62370.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NYAKOSOBA'): 33.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA QABA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEMONKONG'): 8.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSOLOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PEKA'): 866.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PITSENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEBOCHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SETLAKALLENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIPHIRING'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LERIBEMORENENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HLEOHENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MERITING'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_CALEDON'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHOBONG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAMOTSOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAKAMOHO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SERUTLE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSIKOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QHOLAQHOE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_CHAFO'): 38.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NYENYE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_CORNEXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LISEMENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSIFALIMALI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSEHLANYANE'): 24.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAZENOD_AIRPORT'): 74041.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHLASELA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOTSOLA'): 79.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPOTENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKHOROANA'): 11.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEKOKOANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOLONYAMA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAMATHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEFIKENG'): 11.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THAKABANNA'): 143.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIQHOBONG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LETSENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKOAE2'): 1209.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BAFALI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_METOLONG'): 4332.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MONONTSA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOREMOHOLO'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHANYANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MABOLOKA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SETALA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NTJABANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NQECHANE'): 388.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA_NTSELI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOABONG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTHAE_MINE'): 1794.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_POLIHALI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PONOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATSOKU'): 14994,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOKHONG'): 98651.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIQHOBONG_MINE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KAO_MINE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TLOKOTSING'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA SHOAEPANE'): 26846.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATLAKENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MANAMANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PANENG'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABA-NTSHO'): 36506.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA KOATSI'): 20267.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MARAKABEI'): 47159.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPHOLANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SOLANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTETE_SEKHOBE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QHOALI_HA_KELEBONE'): 8512.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOTLONG_VALLEY'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKOAE_1'): 226.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIQOBONG'): 854.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KETANE'): 1215.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KETANE_TIPING'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHATIBE_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHOSHANENG'): 21746.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_UPPER_MOYENI'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAMAEPHO'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTSEKUOA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOBATSI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKHAKHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SANQEBETHU'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAMOHAPI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSAKHOLO'): 27.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KUBUNG'): 1925.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIKHOELE'): 84803.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA_NTOPO'): 27.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HOLYCROSS'): 223.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKHALENG'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALIMONG'): 16399.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TIPING'): 107946.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEROALANKHOANA'): 91890.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOSENEKE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHLAKACHANENG'): 1213.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA_MPUTANA'): 22.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSIME'): 46.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA RAMABANTA'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEPHAPHOS GATE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SETIBING'): 60133.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_VANROOYAN'): 22.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEBELONYANE'): 1254.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATEBENG'): 56130.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HIGHVELT'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOINYATSO'): 400,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSOLO2'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA_ECOL'): 19.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOTLONG_TOWN'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BESELE'): 7269.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LOWER_THAMAE'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LESOTHOSUN'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LAKESIDE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_VICTORIA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MANONYANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_STATE LIBRARY'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASERU WEST'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_FOKOTHI'): 11.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MABOTE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_STADIUM'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ABIA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSANE_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ROYAL PALACE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QOALING'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ETLHQ'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_INDUSTRIAL1'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LITHOTENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LESOTHOHIGHSCHOOL'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASIANOKENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTIMPOSO'): 22,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LITHABANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HILLSVIEW'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSANE_INDUSTRIAL'): 1800.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HATSIU'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HATHAMAE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA1'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TIKOE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEQELE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_FLORIDA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QOALING_HAMAMPHO'): 7116.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKOANYANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MABOTEPOLICE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_FOSO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_AIRPORT'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THUATHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SHALABENG'): 7272.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOROKHOANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_INDUSTRIAL2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NALELI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HLALELE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASERUSUN'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_CARLTONCENTRE'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RALEJOE'): 63.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ROMAEXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASOWE'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOALABATA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEAPOINT'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PENAPENA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATALA'): 84816.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NNELESE'): 43572,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSOLO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPELENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ROMA_HA_SKAUT'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA_WILLIS'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_FOSO_2'): 11377.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA_DLM'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOSHOESHOE_II'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSANE_LESIA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSANE_LEKHOOA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LOWER_SEOLI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA_SELESO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEQELE_BUSSTOP'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEKAMANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTSEMOCHA'): 27.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEBOTHOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOSOFO'): 600,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASANA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBETSOANA_LECOOP'): 30.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOCHABELA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HATLELAI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MORIFI'): 99.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MPHAKI'): 1263.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEBAPALA'): 5984.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEHLABATHEBE'): 46127.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SOURU'): 124.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BRAAKFONTEIN'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA MPITI'): 124.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PHATLALLA'): 48398.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOTLONG_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOUNT MOOROSI'): 71.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTSEMOCHA2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATALA_PHASE2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAJAHENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NHTC'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPETLA'): 18780.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEQELE_2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOALABATA_PRIMARY'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBELU'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TSOSANE_PRIMARY'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKHOATHI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTLOHELOA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAZENOD'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSANELESIA2'): 599.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PARLIAMENT'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASOWE_1'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEKAMANENG_2'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RATJOMOSE'): 294.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MANTSEBO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PARAY_HOSPITAL'): 70482.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PONTSENG'): 36209.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOFOKA'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ST_AGNES'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ROMA_HATABUTLE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TEYATEYANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BEREA_HOSPITAL'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BUTHA BUTHE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LERIBE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPUTSOE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIKILENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ST_ROSE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHETHOANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SANIBORDER'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOTISPHOLA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOKHOTLONGHILL'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_NYENYE_2'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SHEPESELI'): 769.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MARABENG'): 15474.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MASERUMALL_2'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALETSUNYANE'): 8718.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KUBAKE'): 4930,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PULANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATHATA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MANKOANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAKEPI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATUKENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKOPO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PALACE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAMOPELI'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATLAMENG'): 16.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA SETHO'): 897,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATHATA2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAQELE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAHLAKAPESE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BUOASONO'): 19.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QACHA'): 127.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAMOROBA'): 71.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA SEHLOHO'): 5759.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QUTHING_LNBS'): 38907.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_DR_GUESTHOUSE'): 19.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHUBELU_VALLEY'): 151763.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BOKONG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ALWYNSKOP'): 177.0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIQALABENG'): 124.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAMOKHELE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOHALESHOEKHILL'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA-NTHO'): 176.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATHOLENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PHAHAMENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPHOHLOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KOLO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABANA_MORENA'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALUMENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LELOALENG'): 8.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_ST_STEPHENS'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_QALAKHENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEROPONG'): 124.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_GOLDEN_TOWER'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABA TSEKA_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HALEPOLESA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALEALEA'): 27.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MPHARANE'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THABA_PUTSOA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAPOTENG_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_TOLOANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PITSENG_POLICE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALESAOANA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_BUTHABUTHE_TLOKOENG'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LEVISNEK'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KHAFUNG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAQOALA_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HAMOTAU'): 16.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_THETSINYANE'): 1201.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HATLALI'): 38.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEHONGHONG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAMAEBANA'): 25640,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_KAONYANE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LIKHELIKA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_JANTEU'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAPOLEBOEA'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MATSOAING'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_SEATE'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALINGOANENG'): 718.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MALEHLAKANA'): 5.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_LINAKANENG_2'): 13.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MOTENG_2'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_PATISING'): 51344.25,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MAKHANGOA'): 6673.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAMATSELISO'): 29779.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MESITSANENG'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA SEHAPA'): 122425.5,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_HA TSEPO'): 0,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_RAPOKOLANA'): 101450.75,
#  (datetime.datetime(2025, 4, 29, 0, 0), '3G_MJANYANE'): 130.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THABA-TSEKA HILL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIBONO'): 123.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAFETENG EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LCE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THABALIHLOLO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LINAKANENG'): 16085.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MALEFILOANE'): 1250.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MALEFILOANE REPEATER'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_QHOASING'): 4135.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NKA-O-BEE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BULARA'): 44.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BAKING'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KOTA'): 33.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTENG'): 44.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPUTSOE_WASA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOSETOA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SESHOTE'): 8.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_POPA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NKOKAMELE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ST. JAMES'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEJONE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TLOKOENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAFETENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAHLONG'): 24.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SILOE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATELILE'): 55.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOHALE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOHALESHOEK EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA NYANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KATSE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEOKA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), 'SGSN'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NGOAJANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BEREAPLATEAU'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAQHAKA'): 19.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_AME'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LESOBENG'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ROTHE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAHLOENYENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAJA'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAMOKHALINYANE'): 1001.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAJANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MORIJA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THABABOSIU'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HALEKOALA'): 22.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MACHACHE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_RADIOLESOTHO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BATI'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKOETJE'): 233.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MALAOANENG'): 8880.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MANTSONYANE'): 16.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATHUOANENG'): 62699.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NYAKOSOBA'): 30.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA QABA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEMONKONG'): 8.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSOLOANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PEKA'): 73269,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PITSENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEBOCHE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SETLAKALLENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIPHIRING'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LERIBEMORENENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HLEOHENG'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MERITING'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_CALEDON'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAHOBONG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAMOTSOANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAKAMOHO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SERUTLE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSIKOANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_QHOLAQHOE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_CHAFO'): 41.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NYENYE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_CORNEXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LISEMENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSIFALIMALI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSEHLANYANE'): 22.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAZENOD_AIRPORT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAHLASELA'): 47,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOTSOLA'): 77.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPOTENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKHOROANA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEKOKOANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KOLONYAMA'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAMATHE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEFIKENG'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THAKABANNA'): 200.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIQHOBONG'): 55.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LETSENG'): 47,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKOAE2'): 258.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BAFALI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_METOLONG'): 1216.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MONONTSA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOREMOHOLO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHANYANE'): 8890.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MABOLOKA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SETALA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NTJABANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NQECHANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA_NTSELI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOABONG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTHAE_MINE'): 47,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_POLIHALI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PONOANE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATSOKU'): 14158.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOKHONG'): 98443.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIQHOBONG_MINE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KAO_MINE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TLOKOTSING'): 327.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA SHOAEPANE'): 34604.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATLAKENG'): 27113.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MANAMANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PANENG'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THABA-NTSHO'): 37501.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA KOATSI'): 19243.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MARAKABEI'): 514.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPHOLANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SOLANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTETE_SEKHOBE'): 49.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_QHOALI_HA_KELEBONE'): 2888.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOTLONG_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKOAE_1'): 288.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIQOBONG'): 857.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KETANE'): 252.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KETANE_TIPING'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHATIBE_VALLEY'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHOSHANENG'): 19193.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_UPPER_MOYENI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAMAEPHO'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTSEKUOA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOBATSI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKHAKHE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SANQEBETHU'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_RAMOHAPI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSAKHOLO'): 22.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KUBUNG'): 4601.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIKHOELE'): 98599.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA_NTOPO'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HOLYCROSS'): 159.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKHALENG'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MALIMONG'): 182008.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TIPING'): 118085.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEROALANKHOANA'): 93894.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOSENEKE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAHLAKACHANENG'): 255.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA_MPUTANA'): 24.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSIME'): 16.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA RAMABANTA'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEPHAPHOS GATE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SETIBING'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_VANROOYAN'): 16.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEBELONYANE'): 255.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATEBENG'): 57616.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HIGHVELT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOINYATSO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSOLO2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA_ECOL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOTLONG_TOWN'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BESELE'): 33827.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LOWER_THAMAE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LESOTHOSUN'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LAKESIDE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_VICTORIA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MANONYANE'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_STATE LIBRARY'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASERU WEST'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_FOKOTHI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MABOTE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_STADIUM'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ABIA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THETSANE_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ROYAL PALACE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_QOALING'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ETLHQ'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_INDUSTRIAL1'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LITHOTENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LESOTHOHIGHSCHOOL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASIANOKENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTIMPOSO'): 5810.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LITHABANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HILLSVIEW'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THETSANE_INDUSTRIAL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HATSIU'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HATHAMAE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA1'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TIKOE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEQELE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_FLORIDA'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_QOALING_HAMAMPHO'): 73408.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKOANYANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MABOTEPOLICE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_FOSO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_AIRPORT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THUATHE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SHALABENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOROKHOANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_INDUSTRIAL2'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NALELI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HLALELE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASERUSUN'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_CARLTONCENTRE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_RALEJOE'): 44.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ROMAEXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASOWE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KOALABATA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEAPOINT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PENAPENA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATALA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NNELESE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSOLO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPELENG'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ROMA_HA_SKAUT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA_WILLIS'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_FOSO_2'): 31405.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA_DLM'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOSHOESHOE_II'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THETSANE_LESIA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THETSANE_LEKHOOA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LOWER_SEOLI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA_SELESO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEQELE_BUSSTOP'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEKAMANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTSEMOCHA'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEBOTHOANE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOSOFO'): 3282.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASANA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBETSOANA_LECOOP'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BOCHABELA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HATLELAI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MORIFI'): 85.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MPHAKI'): 247.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEBAPALA'): 14946.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEHLABATHEBE'): 45835.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SOURU'): 160.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BRAAKFONTEIN'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA MPITI'): 127.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PHATLALLA'): 99149.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOTLONG_EXCHANGE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOUNT MOOROSI'): 30.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTSEMOCHA2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATALA_PHASE2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAJAHENG'): 8.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NHTC'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPETLA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LEQELE_2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KOALABATA_PRIMARY'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KHUBELU'): 11.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TSOSANE_PRIMARY'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKHOATHI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOTLOHELOA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAZENOD'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_THETSANELESIA2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PARLIAMENT'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASOWE_1'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SEKAMANENG_2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_RATJOMOSE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MANTSEBO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PARAY_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PONTSENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOFOKA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ST_AGNES'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ROMA_HATABUTLE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_TEYATEYANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BEREA_HOSPITAL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_BUTHA BUTHE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LERIBE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAPUTSOE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_LIKILENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_ST_ROSE'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHETHOANENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SANIBORDER'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KOTISPHOLA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MOKHOTLONGHILL'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_NYENYE_2'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_SHEPESELI'): 13505.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MARABENG'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MASERUMALL_2'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MALETSUNYANE'): 16.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_KUBAKE'): 5619.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PULANE'): 3119.0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATHATA'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MANKOANENG'): 2097,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAKEPI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATUKENG'): 2915.75,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MAKOPO'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_PALACE'): 5.5,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HAMOPELI'): 0,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_MATLAMENG'): 19.25,
#  (datetime.datetime(2025, 4, 30, 0, 0), '3G_HA SETHO'): 0,
#  ...}

# %%
wb = xl.Workbook()
ws=wb.active

# %%
ROUTER_LOOKUP = {"ABIA":"ABIA-6804_1",
"AIRPORT":"MZD_6804E_1",
"ALWYNSKOP":"QCG-6804_1",
"AME":"HQ-M6000-8S",
"BAFALI":"MQQ-6804_1",
"BAKING":"MPU-6804_1",
"BATI":"NYA-6804_1",
"BEREA PLATEAU":"BEP-6804-1",
"BEREA_HOSPITAL":"TYG-6804_1",
"BEREAPLATEAU":"BEP-6804-1",
"BESELE":"ABIA-6804_1",
"BOBATSI":"MQQ-6804_1",
"BOCHABELA":"MBT-6804_1",
"BOINYATSO":"MBT-6804_1",
"BOROKHOANENG":"BRG-6804_1",
"BOSOFO":"ABIA-6804_1",
"BOTSOLA":"LRB-6804_1",
"BRAAKFONTEIN":"MOK-6804_1",
"BULARA":"BHB-6804_1",
"BUOASONO":"MBT-6804_1",
"BUTHA BUTHE":"BHB-6804_1",
"BUTHABUTHE":"BHB-6804_1",
"BUTHABUTHE_TLOKOENG":"BHB-6804_1",
"CALEDON":"BHB-6804_1",
"CARLTONCENTRE":"HQ-M6000-8S",
"CHAFO":"LRB-6804_1",
"CORNEXCHANGE":"MPU-6804_1",
"DR_GUESTHOUSE":"MBT-6804_1",
"ETLHQ":"MSU-8905E-CORE-SW01",
"FLORIDA":"HQ-M6000-8S",
"FOKOTHI":"HQ-M6000-8S",
"FOSO":"MBT-6804_1",
"FOSO_2":"MBT-6804_1",
"GOLDEN_TOWER":"MAE-6804_1",
"HA KOATSI":"NYA-6804_1",
"HA MPITI":"QSK-6804_1",
"HA NYANE":"NYA-6804_1",
"HA QABA":"MOK-6804_1",
"HA RAMABANTA":"MOK-6804_1",
"HA SEHAPA":"QSK-6804_1",
"HA SEHLOHO":"QSK-6804_1",
"HA SETHO":"THE-M6000-8S",
"HA SHOAEPANE":"MRJ-6804_1",
"HA TSEPO":"MOK-6804_1",
"HA_MPUTANA":"NYA-6804_1",
"HA_NTINA":"MPU-6804_1",
"HA_NTOPO":"NYA-6804_1",
"HA_NTSELI":"TTA-6804_1",
"HA_SELESO":"ABIA-6804_1",
"HAKAMOHO":"BHB-6804_1",
"HAKEPI":"TYG-6804_1",
"HAKOATSI":"NYA-6804_1",
"HALEKOALA":"MZD_6804E_1",
"HALEPOLESA":"MAE-6804_1",
"HAMAEPHO":"NYA-6804_1",
"HAMOKHALINYANE":"MRJ-6804_1",
"HAMOPELI":"BHB-6804_1",
"HAMOTAU":"NYA-6804_1",
"HAMOTSOANE":"BHB-6804_1",
"HANTHO":"QCG-6804_1",
"HA-NTHO":"QCG-6804_1",
"HATHAMAE":"BRG-6804_1",
"HATLALI":"BEP-6804-1",
"HATLELAI":"ABIA-6804_1",
"HATSEPO":"MOK-6804_1",
"HATSIU":"MBT-6804_1",
"HIGHVELT":"MBT-6804_1",
"HILLSVIEW":"HQ-M6000-8S",
"HLALELE":"THE-M6000-8S",
"HLEOHENG":"MPU-6804_1",
"HOLYCROSS":"QCG-6804_1",
"INDUSTRIAL1":"HQ-M6000-8S",
"INDUSTRIAL2":"HQ-M6000-8S",
"JANTEU":"MQQ-6804_1",
"KAO":"BHB-6804_1",
"KAO_MINE":"BHB-6804_1",
"KAONYANE":"MAHLASELA (L3 Switch)",
"KATSE":"TTA-6804_1",
"KETANE":"QCG-6804_1",
"KETANE_TIPING":"NYA-6804_1",
"KHAFUNG":"TYG-6804_1",
"KHANYANE":"LRB-6804_1",
"KHATIBE_VALLEY":"BHB-6804_1",
"KHOSHANENG":"TTA-6804_1",
"KHUBELU":"ABIA-6804_1",
"KHUBELU_VALLEY":"MAPHOLANENG (L3 Switch)",
"KHUBETSOANA_DLM":"MBT-6804_1",
"KHUBETSOANA_LECOOP":"MBT-6804_1",
"KHUBETSOANA_WILLIS":"MBT-6804_1",
"KHUBETSOANA1":"MBT-6804_1",
"KHUBETSOANA2":"MBT-6804_1",
"KHUBETSOANADLM":"MBT-6804_1",
"KHUBETSOANAWILLIS":"MBT-6804_1",
"KOALABATA":"MBT-6804_1",
"KOALABATA_PRIMARY":"MBT-6804_1",
"KOLO":"BEP-6804-1",
"KOLONYAMA":"TYG-6804_1",
"KOTA":"LRB-6804_1",
"KOTISPHOLA":"MQQ-6804_1",
"KUBAKE":"MOK-6804_1",
"KUBUNG":"QCG-6804_1",
"LAKESIDE":"HQ-M6000-8S",
"LCE":"HQ-M6000-8S",
"LEBELONYANE":"QCG-6804_1",
"LEJONE":"TTA-6804_1",
"LEKOKOANENG":"TYG-6804_1",
"LELOALENG":"NYA-6804_1",
"LEQELE":"BRG-6804_1",
"LEQELE_2":"BRG-6804_1",
"LEQELE_BUSSTOP":"BRG-6804_1",
"LERIBE":"LRB-6804_1",
"LERIBE MORENENG":"BHB-6804_1",
"LERIBEMORENENG":"BHB-6804_1",
"LEROPONG":"QSK-6804_1",
"LESOBENG":"NYA-6804_1",
"LESOTHOHIGHSCHOOL":"HQ-M6000-8S",
"LESOTHOSUN":"HQ-M6000-8S",
"LETSENG":"LETS_6804_1",
"LEVISNEK":"BHB-6804_1",
"LIBONO":"BHB-6804_1",
"LIKHELIKA":"BHB-6804_1",
"LIKHOELE":"MAE-6804_1",
"LIKILENG":"BHB-6804_1",
"LINAKANENG":"TTA-6804_1",
"LINAKANENG_2":"TTA-6804_1",
"LIPHIRING":"MOK-6804_1",
"LIQALABENG":"QSK-6804_1",
"LIQHOBONG":"BHB-6804_1",
"LIQHOBONG_MINE":"TTA-6804_1",
"LIQOBONG":"BHB-6804_1",
"LISEMENG":"LRB-6804_1",
"LITHABANENG":"BRG-6804_1",
"LITHOTENG":"ABIA-6804_1",
"LOWER_SEOLI":"BRG-6804_1",
"LOWER_THAMAE":"BRG-6804_1",
"LOWERSEOLI":"BRG-6804_1",
"MABOLOKA":"MQQ-6804_1",
"MABOTE":"MBT-6804_1",
"MABOTEPOLICE":"MBT-6804_1",
"MACHACHE":"MZD_6804E_1",
"MAFETENG":"MAE-6804_1",
"MAFETENG EXCHANGE":"MAE-6804_1",
"MAFETENG_EXCHANGE":"MAE-6804_1",
"MAHLAKACHANENG":"QCG-6804_1",
"MAHLAKAPESE":"LRB-6804_1",
"MAHLASELA":"LETS_6804_1",
"MAHLOENYENG":"MRJ-6804_1",
"MAHLONG":"NYA-6804_1",
"MAHOBONG":"LRB-6804_1",
"MAJA":"MZD_6804E_1",
"MAJAHENG":"TYG-6804_1",
"MAJANE":"MRJ-6804_1",
"MAKHAKHE":"MRJ-6804_1",
"MAKHALENG":"MOK-6804_1",
"MAKHOATHI":"BRG-6804_1",
"MAKHOROANA":"MPU-6804_1",
"MAKOAE_1":"QCG-6804_1",
"MAKOAE2":"QCG-6804_1",
"MAKOANYANE":"BRG-6804_1",
"MAKOETJE":"MRJ-6804_1",
"MAKOPO":"BHB-6804_1",
"MALAOANENG":"LRB-6804_1",
"MALEALEA":"MOK-6804_1",
"MALEFILOANE":"MQQ-6804_1",
"MALEFILOANE REPEATER":"MQQ-6804_1",
"MALEHLAKANA":"TTA-6804_1",
"MALESAOANA":"LRB-6804_1",
"MALETSUNYANE":"NYA-6804_1",
"MALIMONG":"TYG-6804_1",
"MALINGOANENG":"MQQ-6804_1",
"MALUMENG":"MAE-6804_1",
"MAMAEBANA":"MOK-6804_1",
"MAMATHE":"TYG-6804_1",
"MANAMANENG":"TTA-6804_1",
"MANKOANENG":"LRB-6804_1",
"MANONYANE":"HQ-M6000-8S",
"MANTSEBO":"MZD_6804E_1",
"MANTSONYANE":"NYA-6804_1",
"MAPELENG":"MBT-6804_1",
"MAPETLA":"THE-M6000-8S",
"MAPHOHLOANE":"MOK-6804_1",
"MAPHOLANENG":"MQQ-6804_1",
"MAPOTENG":"MPU-6804_1",
"MAPOTENG_EXCHANGE":"MPU-6804_1",
"MAPUTSOE":"MPU-6804_1",
"MAPUTSOE_WASA":"MPU-6804_1",
"MAPUTSOEWASA":"MPU-6804_1",
"MAQELE":"MPU-6804_1",
"MAQHAKA":"MBT-6804_1",
"MAQOALA_VALLEY":"MOK-6804_1",
"MARABENG":"MBT-6804_1",
"MARAKABEI":"NYA-6804_1",
"MASANA":"MZD_6804E_1",
"MASERU WEST":"HQ-M6000-8S",
"MASERUMALL":"MSU-8905E-CORE-SW01",
"MASERUMALL_2":"HQ-M6000-8S",
"MASERUSUN":"HQ-M6000-8S",
"MASERUWEST":"HQ-M6000-8S",
"MASIANOKENG":"THE-M6000-8S",
"MASOWE":"THE-M6000-8S",
"MASOWE_1":"THE-M6000-8S",
"MATALA":"BRG-6804_1",
"MATALA_PHASE2":"BRG-6804_1",
"MATEBENG":"QSK-6804_1",
"MATELILE":"MRJ-6804_1",
"MATHATA":"MPU-6804_1",
"MATHATA2":"MPU-6804_1",
"MATHOLENG":"MAE-6804_1",
"MATHUOANENG":"MQQ-6804_1",
"MATLAKENG":"BHB-6804_1",
"MATLAMENG":"LRB-6804_1",
"MATSOAING":"MQQ-6804_1",
"MATSOKU":"TTA-6804_1",
"MATUKENG":"MPU-6804_1",
"MAZENOD":"MZD_6804E_1",
"MAZENOD_AIRPORT":"MZD_6804E_1",
"MERITING":"MOK-6804_1",
"MESITSANENG":"MOK-6804_1",
"METOLONG":"BEP-6804-1",
"MJANYANE":"QCG-6804_1",
"MOFOKA":"MZD_6804E_1",
"MOHALE":"NYA-6804_1",
"MOHALESHOEK EXCHANGE":"MOK-6804_1",
"MOHALESHOEKHILL":"MOK-6804_1",
"MOKHETHOANENG":"MBT-6804_1",
"MOKHOABONG":"QSK-6804_1",
"MOKHOKHONG":"MZD_6804E_1",
"MOKHOTLONG_EXCHANGE":"MQQ-6804_1",
"MOKHOTLONG_TOWN":"MQQ-6804_1",
"MOKHOTLONG_VALLEY":"MQQ-6804_1",
"MOKHOTLONGEXCHANGE":"MQQ-6804_1",
"MOKHOTLONGHILL":"MQQ-6804_1",
"MONONTSA":"BHB-6804_1",
"MOREMOHOLO":"MQQ-6804_1",
"MORIFI":"MOK-6804_1",
"MORIJA":"MRJ-6804_1",
"MOSALEMANE":"MPU-6804_1",
"MOSENEKE":"MOK-6804_1",
"MOSETOA":"TTA-6804_1",
"MOSHOESHOE_II":"HQ-M6000-8S",
"MOSHOESHOEII":"HQ-M6000-8S",
"MOTENG":"BHB-6804_1",
"MOTENG_2":"BHB-6804_1",
"MOTETE_SEKHOBE":"LETS_6804_1",
"MOTHAE_MINE":"LETS_6804_1",
"MOTIMPOSO":"MBT-6804_1",
"MOTLOHELOA":"MZD_6804E_1",
"MOTSEKUOA":"MRJ-6804_1",
"MOTSEMOCHA":"MBT-6804_1",
"MOTSEMOCHA2":"MBT-6804_1",
"MOTSOANE":"BHB-6804_1",
"MOUNT MOOROSI":"QCG-6804_1",
"MPHAKI":"QCG-6804_1",
"MPHARANE":"MOK-6804_1",
"NALELI":"MBT-6804_1",
"NGOAJANE":"BHB-6804_1",
"NHTC":"BRG-6804_1",
"NKA-O-BEE":"TTA-6804_1",
"NKOKAMELE":"MQQ-6804_1",
"NNELESE":"BRG-6804_1",
"NQECHANE":"BHB-6804_1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ",
"NTJABANE":"TYG-6804_1",
"NYAKOSOBA":"BEP-6804-1",
"NYENYE":"MPU-6804_1",
"NYENYE_2":"MPU-6804_1",
"PALACE":"TYG-6804_1",
"PANENG":"MQQ-6804_1",
"PARAY_HOSPITAL":"TTA-6804_1",
"PARLIAMENT":"HQ-M6000-8S",
"PATISING":"MQQ-6804_1",
"PEKA":"TYG-6804_1",
"PENAPENA":"THE-M6000-8S",
"PHAHAMENG":"MAE-6804_1",
"PHATLALLA":"MOK-6804_1",
"PITSENG":"LRB-6804_1",
"PITSENG_POLICE":"LRB-6804_1",
"POLIHALI":"MQQ-6804_1",
"PONOANE":"MZD_6804E_1",
"PONTSENG":"TTA-6804_1",
"POPA":"MQQ-6804_1",
"PULANE":"MZD_6804E_1",
"QACHA":"QSK-6804_1",
"QACHASNEK":"QSK-6804_1",
"QALAKHENG":"MOK-6804_1",
"QEME_LIKOTSI":"THE-M6000-8S",
"QHOALI_HA_KELEBONE":"QCG-6804_1",
"QHOASING":"QCG-6804_1",
"QHOLAQHOE":"BHB-6804_1",
"QOALING":"BRG-6804_1",
"QOALING_HAMAMPHO":"THE-M6000-8S",
"QOALINGHAMAMPHO":"THE-M6000-8S",
"QUTHING_LNBS":"QCG-6804_1",
"RADIOLESOTHO":"HQ-M6000-8S",
"RALEJOE":"MZD_6804E_1",
"RAMATSELISO":"QSK-6804_1",
"RAMATSHELISO":"QSK-6804_1",
"RAMOHAPI":"MAE-6804_1",
"RAMOKHELE":"MAE-6804_1",
"RAMOROBA":"QSK-6804_1",
"RAPOKOLANA":"NYA-6804_1",
"RAPOLEBOEA":"MOK-6804_1",
"RATJOMOSE":"THE-M6000-8S",
"ROMA_HA_SKAUT":"ROM-6804_1",
"ROMA_HASKAUT":"ROM-6804_1",
"ROMA_HATABUTLE":"ROM-6804_1",
"ROMAEXCHANGE":"ROM-6804_1",
"ROTHE":"MRJ-6804_1",
"ROYAL PALACE":"HQ-M6000-8S",
"ROYALPALACE":"HQ-M6000-8S",
"SANIBORDER":"MQQ-6804_1",
"SANQEBETHU":"MQQ-6804_1",
"SEAPOINT":"HQ-M6000-8S",
"SEATE":"MQQ-6804_1",
"SEBAPALA":"QCG-6804_1",
"SEBOCHE":"BHB-6804_1",
"SEBOTHOANE":"LRB-6804_1",
"SEFIKENG":"THE-M6000-8S",
"SEHLABATHEBE":"QSK-6804_1",
"SEHONGHONG":"MQQ-6804_1",
"SEHONGHONG":"TTA-6804_1",
"SEKAMANENG":"MBT-6804_1",
"SEKAMANENG_2":"MBT-6804_1",
"SELESO":"ABIA-6804_1",
"SEMONKONG":"NYA-6804_1",
"SEOKA":"NYA-6804_1",
"SEPHAPHOS GATE":"MAE-6804_1",
"SEROALANKHOANA":"TTA-6804_1",
"SERUTLE":"BHB-6804_1",
"SESHOTE":"TTA-6804_1",
"SETALA":"NYA-6804_1",
"SETIBING":"BEP-6804-1",
"SETLAKALLENG":"BHB-6804_1",
"SGSN":"MPBN_Switch",
"SHALABENG":"ABIA-6804_1",
"SHEPESELI":"BHB-6804_1",
"SILOE":"MAE-6804_1",
"SOLANE":"TTA-6804_1",
"SOURU":"QSK-6804_1",
"ST. JAMES":"MQQ-6804_1",
"ST_AGNES":"TYG-6804_1",
"ST_ROSE":"TYG-6804_1",
"ST_STEPHENS":"MOK-6804_1",
"STADIUM":"HQ-M6000-8S",
"STATE LIBRARY":"HQ-M6000-8S",
"STATELIBRARY":"HQ-M6000-8S",
"STJAMES":"MQQ-6804_1",
"TEYATEYANENG":"TYG-6804_1",
"THABA TSEKA_EXCHANGE":"TTA-6804_1",
"THABA TSEKA_HILL":"TTA-6804_1",
"THABA_PUTSOA":"BEP-6804-1",
"THABABOSIU":"BRG-6804_1",
"THABALIHLOLO":"TTA-6804_1",
"THABANA_MORENA":"MAE-6804_1",
"THABANENG":"MAE-6804_1",
"THABA-NTSHO":"MQQ-6804_1",
"THABA-TSEKA HILL":"TTA-6804_1",
"THAKABANNA":"BHB-6804_1",
"THETSANE_HOSPITAL":"THE-M6000-8S",
"THETSANE_INDUSTRIAL":"THE-M6000-8S",
"THETSANE_LEKHOOA":"THE-M6000-8S",
"THETSANE_LESIA":"THE-M6000-8S",
"THETSANEHOSPITAL":"THE-M6000-8S",
"THETSANEINDUSTRIAL":"THE-M6000-8S",
"THETSANELEKHOOA":"THE-M6000-8S",
"THETSANELESIA":"THE-M6000-8S",
"THETSANELESIA2":"THE-M6000-8S",
"THETSINYANE":"QCG-6804_1",
"THETSINYANE":"Lebolonyane (L3 Switch)",
"THUATHE":"BEP-6804-1",
"TIKOE":"THE-M6000-8S",
"TIPING":"MOK-6804_1",
"TLOKOENG":"MQQ-6804_1",
"TLOKOTSING":"MAE-6804_1",
"TOLOANE":"MRJ-6804_1",
"TSAKHOLO":"MAE-6804_1",
"TSEHLANYANE":"LRB-6804_1",
"TSIFALIMALI":"LRB-6804_1",
"TSIKOANE":"MPU-6804_1",
"TSIME":"BHB-6804_1",
"TSOLO":"THE-M6000-8S",
"TSOLO2":"THE-M6000-8S",
"TSOLOANE":"MOK-6804_1",
"TSOSANE":"MBT-6804_1",
"TSOSANE_PRIMARY":"MBT-6804_1",
"UPPER_MOYENI":"QCG-6804_1",
"UPPERMOYENI":"QCG-6804_1",
"VANROOYAN":"MAE-6804_1",
"VANROOYEN":"MAE-6804_1",
"VICTORIA":"HQ-M6000-8S",
"KHUBETSOANA_ECOL":"MBT-6804_1",
"BOKONG":"TTA-6804_1",
"MAKHANGOA":"TTA-6804_1",
"HA TLALI":"BEP-6804-1",
"THABA NTSO":"MQQ-6804_1",
"HA MOSITI":"LRB-6804_1"
                }

# %%
routers = dict()
for key in ROUTER_LOOKUP:
    if ROUTER_LOOKUP[key] in routers:
        routers[ROUTER_LOOKUP[key]].append(key)
    else:
        routers[ROUTER_LOOKUP[key]]  = [key]

# %%
routers['MSU-8905E-CORE-SW01']
# Out:
# ['ETLHQ', 'MASERUMALL']

# %%
insert_data(umts_loss,routers,ws)

# %%
wb.save('packetloss_test.xlsx')
